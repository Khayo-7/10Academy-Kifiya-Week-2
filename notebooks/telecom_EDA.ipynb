# %%
# notebooks/example_notebook.ipynb

import sys
import os
sys.path.append('..')

from scripts.vizualize import *
from scripts.eda_utils import *
from scripts.sql_queries import *
from scripts.aggregation import *
from scripts.preprocessing.data_loaders import *
from scripts.preprocessing.data_cleaning import *
from scripts.preprocessing.data_transformation import *
# from scripts.preprocessing.data_loaders import load_data_to_db, load_data_from_postgres_db, load_data_using_sqlalchemy
# from scripts.sql_queries import get_unique_imsi_count, get_average_duration, get_total_data_usage, execute_telecom_queries
# from scripts.vizualize import plot_histogram

# %%
query = "SELECT * FROM xdr_data;"  
df = load_data_from_postgres_db(query)
df
# Out:
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\notebooks\..\scripts\preprocessing\data_loaders.py:26: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0       1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1       1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2       1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3       1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4       1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
# ...           ...           ...            ...           ...
# 149996    81230.0  2.082022e+14   3.365069e+10  3.548311e+13
# 149997    97970.0  2.082019e+14   3.366345e+10  3.566051e+13
# 149998    98249.0  2.082017e+14   3.362189e+10  3.572121e+13
# 149999    97910.0  2.082021e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#            Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0       9.16456699548519E+015  ...        1.585461e+07        2.501332e+06
# 1                     L77566A  ...        2.024740e+07        1.911173e+07
# 2                     D42335A  ...        1.972566e+07        1.469958e+07
# 3                     T21824A  ...        2.138812e+07        1.514664e+07
# 4                     D88865A  ...        1.525938e+07        1.896287e+07
# ...                       ...  ...                 ...                 ...
# 149996                D20434A  ...        1.619167e+07        1.176343e+07
# 149997                D10223C  ...        1.387723e+07        8.288284e+06
# 149998                T51102A  ...        2.266051e+07        1.855903e+06
# 149999                L88342B  ...        8.817106e+06        8.305402e+06
# 150000                   None  ...        1.163407e+07        1.100941e+07
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0             8.198936e+06        9.656251e+06       2.780823e+08
# 1             1.833841e+07        1.722713e+07       6.087501e+08
# 2             1.758779e+07        6.163408e+06       2.295846e+08
# 3             1.399465e+07        1.097942e+06       7.995382e+08
# 4             1.712458e+07        4.152180e+05       5.277072e+08
# ...                    ...                 ...                ...
# 149996        1.788370e+07        1.967816e+07       5.266097e+08
# 149997        1.935015e+07        2.129315e+07       6.268931e+08
# 149998        9.963942e+06        5.065760e+06       5.535395e+08
# 149999        3.322253e+06        1.317259e+07       3.525370e+08
# 150000        1.162685e+07        1.100175e+07       4.220447e+08
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0            1.434415e+07      1.717444e+08      8.814393e+06
# 1            1.170709e+06      5.269042e+08      1.505514e+07
# 2            3.956300e+05      4.106926e+08      4.215763e+06
# 3            1.084972e+07      7.490399e+08      1.279728e+07
# 4            3.529801e+06      5.507095e+08      1.391032e+07
# ...                   ...               ...               ...
# 149996       9.197207e+06      3.264510e+06      1.348742e+07
# 149997       4.735033e+06      7.121804e+08      2.457758e+06
# 149998       1.339432e+07      1.211009e+08      1.131473e+07
# 149999       2.529475e+06      8.147131e+08      1.406930e+06
# 150000       8.288398e+06      4.211005e+08      8.264799e+06
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             36749741.0       308879636.0
# 1             53800391.0       653384965.0
# 2             27883638.0       279807335.0
# 3             43324218.0       846028530.0
# 4             38542814.0       569138589.0
# ...                  ...               ...
# 149996        57628851.0       574175259.0
# 149997        39135081.0       666648844.0
# 149998        34912224.0       592786405.0
# 149999        29626096.0       371895920.0
# 150000               NaN               NaN
#
# [150001 rows x 55 columns]

# %%
# Load data from PostgreSQL using SQLAlchemy
df_alchemy = load_data_using_sqlalchemy(query)
df_alchemy
df = df_alchemy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
#  10  Avg RTT DL (ms)                           122172 non-null  float64
#  11  Avg RTT UL (ms)                           122189 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150000 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150000 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               61855 non-null   float64
#  15  TCP UL Retrans. Vol (Bytes)               53352 non-null   float64
#  16  DL TP < 50 Kbps (%)                       149247 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            149247 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             149247 non-null  float64
#  19  DL TP > 1 Mbps (%)                        149247 non-null  float64
#  20  UL TP < 10 Kbps (%)                       149209 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             149209 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            149209 non-null  float64
#  23  UL TP > 300 Kbps (%)                      149209 non-null  float64
#  24  HTTP DL (Bytes)                           68527 non-null   float64
#  25  HTTP UL (Bytes)                           68191 non-null   float64
#  26  Activity Duration DL (ms)                 150000 non-null  float64
#  27  Activity Duration UL (ms)                 150000 non-null  float64
#  28  Dur. (ms).1                               150000 non-null  float64
#  29  Handset Manufacturer                      149429 non-null  object
#  30  Handset Type                              149429 non-null  object
#  31  Nb of sec with 125000B < Vol DL           52463 non-null   float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     57107 non-null   float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  56415 non-null   float64
#  34  Nb of sec with 37500B < Vol UL            19747 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    61684 non-null   float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    38158 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             149246 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             149208 non-null  float64
#  39  Social Media DL (Bytes)                   150001 non-null  float64
#  40  Social Media UL (Bytes)                   150001 non-null  float64
#  41  Google DL (Bytes)                         150001 non-null  float64
#  42  Google UL (Bytes)                         150001 non-null  float64
#  43  Email DL (Bytes)                          150001 non-null  float64
#  44  Email UL (Bytes)                          150001 non-null  float64
#  45  Youtube DL (Bytes)                        150001 non-null  float64
#  46  Youtube UL (Bytes)                        150001 non-null  float64
#  47  Netflix DL (Bytes)                        150001 non-null  float64
#  48  Netflix UL (Bytes)                        150001 non-null  float64
#  49  Gaming DL (Bytes)                         150001 non-null  float64
#  50  Gaming UL (Bytes)                         150001 non-null  float64
#  51  Other DL (Bytes)                          150001 non-null  float64
#  52  Other UL (Bytes)                          150001 non-null  float64
#  53  Total UL (Bytes)                          150000 non-null  float64
#  54  Total DL (Bytes)                          150000 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 62.9+ MB

# %%
df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# std     2.447443e+12  2.241637e+13       619.782739        84.793524
# min     3.360100e+10  4.400152e+11         0.000000         0.000000
# 25%     3.365130e+10  3.546071e+13        32.000000         2.000000
# 50%     3.366371e+10  3.572201e+13        45.000000         5.000000
# 75%     3.368349e+10  8.611970e+13        70.000000        15.000000
# max     8.823971e+14  9.900120e+13     96923.000000      7120.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count            150000.000000  ...        1.500010e+05        1.500010e+05
# mean              13300.045927  ...        1.163407e+07        1.100941e+07
# std               23971.878541  ...        6.710569e+06        6.345423e+06
# min                   0.000000  ...        5.300000e+01        1.050000e+02
# 25%                  43.000000  ...        5.833501e+06        5.517965e+06
# 50%                  63.000000  ...        1.161602e+07        1.101345e+07
# 75%               19710.750000  ...        1.744852e+07        1.651556e+07
# max              378160.000000  ...        2.325910e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        1.500010e+05        1.500010e+05       1.500010e+05
# mean         1.162685e+07        1.100175e+07       4.220447e+08
# std          6.725218e+06        6.359490e+06       2.439675e+08
# min          4.200000e+01        3.500000e+01       2.516000e+03
# 25%          5.777156e+06        5.475981e+06       2.104733e+08
# 50%          1.164222e+07        1.099638e+07       4.234081e+08
# 75%          1.747048e+07        1.650727e+07       6.331742e+08
# max          2.325919e+07        2.201196e+07       8.434419e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       1.500010e+05      1.500010e+05      1.500010e+05
# mean        8.288398e+06      4.211005e+08      8.264799e+06
# std         4.782700e+06      2.432050e+08      4.769004e+06
# min         5.900000e+01      3.290000e+03      1.480000e+02
# 25%         4.128476e+06      2.101869e+08      4.145943e+06
# 50%         8.291208e+06      4.218030e+08      8.267071e+06
# 75%         1.243162e+07      6.316918e+08      1.238415e+07
# max         1.655879e+07      8.434425e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      1.500000e+05      1.500000e+05
# mean       4.112121e+07      4.546434e+08
# std        1.127639e+07      2.441429e+08
# min        2.866892e+06      7.114041e+06
# 25%        3.322201e+07      2.431068e+08
# 50%        4.114331e+07      4.558411e+08
# 75%        4.903424e+07      6.657055e+08
# max        7.833131e+07      9.029696e+08
#
# [8 rows x 50 columns]

# %%
df.isnull().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# 250 Kbps < DL TP < 1 Mbps (%)                  754
# DL TP > 1 Mbps (%)                             754
# UL TP < 10 Kbps (%)                            792
# 10 Kbps < UL TP < 50 Kbps (%)                  792
# 50 Kbps < UL TP < 300 Kbps (%)                 792
# UL TP > 300 Kbps (%)                           792
# HTTP DL (Bytes)                              81474
# HTTP UL (Bytes)                              81810
# Activity Duration DL (ms)                        1
# Activity Duration UL (ms)                        1
# Dur. (ms).1                                      1
# Handset Manufacturer                           572
# Handset Type                                   572
# Nb of sec with 125000B < Vol DL              97538
# Nb of sec with 1250B < Vol UL < 6250B        92894
# Nb of sec with 31250B < Vol DL < 125000B     93586
# Nb of sec with 37500B < Vol UL              130254
# Nb of sec with 6250B < Vol DL < 31250B       88317
# Nb of sec with 6250B < Vol UL < 37500B      111843
# Nb of sec with Vol DL < 6250B                  755
# Nb of sec with Vol UL < 1250B                  793
# Social Media DL (Bytes)                          0
# Social Media UL (Bytes)                          0
# Google DL (Bytes)                                0
# Google UL (Bytes)                                0
# Email DL (Bytes)                                 0
# Email UL (Bytes)                                 0
# Youtube DL (Bytes)                               0
# Youtube UL (Bytes)                               0
# Netflix DL (Bytes)                               0
# Netflix UL (Bytes)                               0
# Gaming DL (Bytes)                                0
# Gaming UL (Bytes)                                0
# Other DL (Bytes)                                 0
# Other UL (Bytes)                                 0
# Total UL (Bytes)                                 1
# Total DL (Bytes)                                 1
# dtype: int64

# %%
df_cleaned = clean_data(df)
df = df_cleaned
df_cleaned.info()
# Out:
# Before cleaning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
#  10  Avg RTT DL (ms)                           122172 non-null  float64
#  11  Avg RTT UL (ms)                           122189 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   150000 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   150000 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               61855 non-null   float64
#  15  TCP UL Retrans. Vol (Bytes)               53352 non-null   float64
#  16  DL TP < 50 Kbps (%)                       149247 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            149247 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             149247 non-null  float64
#  19  DL TP > 1 Mbps (%)                        149247 non-null  float64
#  20  UL TP < 10 Kbps (%)                       149209 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             149209 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            149209 non-null  float64
#  23  UL TP > 300 Kbps (%)                      149209 non-null  float64
#  24  HTTP DL (Bytes)                           68527 non-null   float64
#  25  HTTP UL (Bytes)                           68191 non-null   float64
#  26  Activity Duration DL (ms)                 150000 non-null  float64
#  27  Activity Duration UL (ms)                 150000 non-null  float64
#  28  Dur. (ms).1                               150000 non-null  float64
#  29  Handset Manufacturer                      149429 non-null  object
#  30  Handset Type                              149429 non-null  object
#  31  Nb of sec with 125000B < Vol DL           52463 non-null   float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     57107 non-null   float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  56415 non-null   float64
#  34  Nb of sec with 37500B < Vol UL            19747 non-null   float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    61684 non-null   float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    38158 non-null   float64
#  37  Nb of sec with Vol DL < 6250B             149246 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             149208 non-null  float64
#  39  Social Media DL (Bytes)                   150001 non-null  float64
#  40  Social Media UL (Bytes)                   150001 non-null  float64
#  41  Google DL (Bytes)                         150001 non-null  float64
#  42  Google UL (Bytes)                         150001 non-null  float64
#  43  Email DL (Bytes)                          150001 non-null  float64
#  44  Email UL (Bytes)                          150001 non-null  float64
#  45  Youtube DL (Bytes)                        150001 non-null  float64
#  46  Youtube UL (Bytes)                        150001 non-null  float64
#  47  Netflix DL (Bytes)                        150001 non-null  float64
#  48  Netflix UL (Bytes)                        150001 non-null  float64
#  49  Gaming DL (Bytes)                         150001 non-null  float64
#  50  Gaming UL (Bytes)                         150001 non-null  float64
#  51  Other DL (Bytes)                          150001 non-null  float64
#  52  Other UL (Bytes)                          150001 non-null  float64
#  53  Total UL (Bytes)                          150000 non-null  float64
#  54  Total DL (Bytes)                          150000 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 62.9+ MB
# None
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# std     2.447443e+12  2.241637e+13       619.782739        84.793524
# min     3.360100e+10  4.400152e+11         0.000000         0.000000
# 25%     3.365130e+10  3.546071e+13        32.000000         2.000000
# 50%     3.366371e+10  3.572201e+13        45.000000         5.000000
# 75%     3.368349e+10  8.611970e+13        70.000000        15.000000
# max     8.823971e+14  9.900120e+13     96923.000000      7120.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count            150000.000000  ...        1.500010e+05        1.500010e+05
# mean              13300.045927  ...        1.163407e+07        1.100941e+07
# std               23971.878541  ...        6.710569e+06        6.345423e+06
# min                   0.000000  ...        5.300000e+01        1.050000e+02
# 25%                  43.000000  ...        5.833501e+06        5.517965e+06
# 50%                  63.000000  ...        1.161602e+07        1.101345e+07
# 75%               19710.750000  ...        1.744852e+07        1.651556e+07
# max              378160.000000  ...        2.325910e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        1.500010e+05        1.500010e+05       1.500010e+05
# mean         1.162685e+07        1.100175e+07       4.220447e+08
# std          6.725218e+06        6.359490e+06       2.439675e+08
# min          4.200000e+01        3.500000e+01       2.516000e+03
# 25%          5.777156e+06        5.475981e+06       2.104733e+08
# 50%          1.164222e+07        1.099638e+07       4.234081e+08
# 75%          1.747048e+07        1.650727e+07       6.331742e+08
# max          2.325919e+07        2.201196e+07       8.434419e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       1.500010e+05      1.500010e+05      1.500010e+05
# mean        8.288398e+06      4.211005e+08      8.264799e+06
# std         4.782700e+06      2.432050e+08      4.769004e+06
# min         5.900000e+01      3.290000e+03      1.480000e+02
# 25%         4.128476e+06      2.101869e+08      4.145943e+06
# 50%         8.291208e+06      4.218030e+08      8.267071e+06
# 75%         1.243162e+07      6.316918e+08      1.238415e+07
# max         1.655879e+07      8.434425e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      1.500000e+05      1.500000e+05
# mean       4.112121e+07      4.546434e+08
# std        1.127639e+07      2.441429e+08
# min        2.866892e+06      7.114041e+06
# 25%        3.322201e+07      2.431068e+08
# 50%        4.114331e+07      4.558411e+08
# 75%        4.903424e+07      6.657055e+08
# max        7.833131e+07      9.029696e+08
#
# [8 rows x 50 columns]
# After cleaning:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64848 entries, 92 to 149999
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Bearer Id                                 64848 non-null  float64
#  1   Start                                     64848 non-null  object
#  2   Start ms                                  64848 non-null  float64
#  3   End                                       64848 non-null  object
#  4   End ms                                    64848 non-null  float64
#  5   Dur. (ms)                                 64848 non-null  float64
#  6   IMSI                                      64848 non-null  float64
#  7   MSISDN/Number                             64848 non-null  float64
#  8   IMEI                                      64848 non-null  float64
#  9   Last Location Name                        64723 non-null  object
#  10  Avg RTT DL (ms)                           64848 non-null  float64
#  11  Avg RTT UL (ms)                           64848 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   64848 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   64848 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               64848 non-null  float64
#  15  TCP UL Retrans. Vol (Bytes)               64848 non-null  float64
#  16  DL TP < 50 Kbps (%)                       64848 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            64848 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             64848 non-null  float64
#  19  DL TP > 1 Mbps (%)                        64848 non-null  float64
#  20  UL TP < 10 Kbps (%)                       64848 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             64848 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            64848 non-null  float64
#  23  UL TP > 300 Kbps (%)                      64848 non-null  float64
#  24  HTTP DL (Bytes)                           64848 non-null  float64
#  25  HTTP UL (Bytes)                           64848 non-null  float64
#  26  Activity Duration DL (ms)                 64848 non-null  float64
#  27  Activity Duration UL (ms)                 64848 non-null  float64
#  28  Dur. (ms).1                               64848 non-null  float64
#  29  Handset Manufacturer                      64848 non-null  object
#  30  Handset Type                              64848 non-null  object
#  31  Nb of sec with 125000B < Vol DL           64848 non-null  float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     64848 non-null  float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  64848 non-null  float64
#  34  Nb of sec with 37500B < Vol UL            64848 non-null  float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    64848 non-null  float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    64848 non-null  float64
#  37  Nb of sec with Vol DL < 6250B             64848 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             64848 non-null  float64
#  39  Social Media DL (Bytes)                   64848 non-null  float64
#  40  Social Media UL (Bytes)                   64848 non-null  float64
#  41  Google DL (Bytes)                         64848 non-null  float64
#  42  Google UL (Bytes)                         64848 non-null  float64
#  43  Email DL (Bytes)                          64848 non-null  float64
#  44  Email UL (Bytes)                          64848 non-null  float64
#  45  Youtube DL (Bytes)                        64848 non-null  float64
#  46  Youtube UL (Bytes)                        64848 non-null  float64
#  47  Netflix DL (Bytes)                        64848 non-null  float64
#  48  Netflix UL (Bytes)                        64848 non-null  float64
#  49  Gaming DL (Bytes)                         64848 non-null  float64
#  50  Gaming UL (Bytes)                         64848 non-null  float64
#  51  Other DL (Bytes)                          64848 non-null  float64
#  52  Other UL (Bytes)                          64848 non-null  float64
#  53  Total UL (Bytes)                          64848 non-null  float64
#  54  Total DL (Bytes)                          64848 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 27.7+ MB
# None
#           Bearer Id      Start ms        End ms      Dur. (ms)          IMSI  \
# count  6.484800e+04  64848.000000  64848.000000   64848.000000  6.484800e+04
# mean   1.002549e+19    499.222474    497.336973  105645.630089  2.082015e+14
# std    2.879922e+18    288.039028    287.548464   53662.668754  3.571748e+08
# min    6.917538e+18      0.000000      0.000000    7284.000000  2.082009e+14
# 25%    7.349883e+18    250.000000    252.000000   65641.000000  2.082014e+14
# 50%    7.349883e+18    498.000000    498.000000   98865.500000  2.082015e+14
# 75%    1.311448e+19    748.000000    749.000000  145618.750000  2.082018e+14
# max    1.318654e+19    999.000000    999.000000  244900.000000  2.082022e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   6.484800e+04  6.484800e+04     64848.000000     64848.000000
# mean    3.365623e+10  4.200191e+13        62.098806         8.419444
# std     2.370101e+07  1.721620e+13        38.145449         7.461515
# min     3.360171e+10  4.400152e+11         0.000000         0.000000
# 25%     3.364403e+10  3.540531e+13        30.000000         2.000000
# 50%     3.366142e+10  3.565611e+13        45.000000         5.000000
# 75%     3.366807e+10  3.589791e+13       109.795706        17.662883
# max     3.370000e+10  9.900120e+13       221.000000        39.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count             64848.000000  ...        6.484800e+04        6.484800e+04
# mean                917.953121  ...        1.159000e+07        1.101830e+07
# std                4074.999617  ...        6.706067e+06        6.323092e+06
# min                   0.000000  ...        5.300000e+01        1.610000e+02
# 25%                  34.000000  ...        5.802918e+06        5.561978e+06
# 50%                  46.000000  ...        1.152636e+07        1.104523e+07
# 75%                  62.000000  ...        1.738991e+07        1.651168e+07
# max               49058.000000  ...        2.325881e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        6.484800e+04        6.484800e+04       6.484800e+04
# mean         1.161094e+07        1.097372e+07       4.225990e+08
# std          6.728007e+06        6.351951e+06       2.440674e+08
# min          4.200000e+01        2.260000e+02       2.516000e+03
# 25%          5.777664e+06        5.461299e+06       2.109423e+08
# 50%          1.164990e+07        1.095161e+07       4.248652e+08
# 75%          1.746121e+07        1.648105e+07       6.343947e+08
# max          2.325815e+07        2.201184e+07       8.434260e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       6.484800e+04      6.484800e+04      6.484800e+04
# mean        8.279814e+06      4.201536e+08      8.255999e+06
# std         4.778230e+06      2.436100e+08      4.764368e+06
# min         1.130000e+02      3.290000e+03      1.480000e+02
# 25%         4.117991e+06      2.093789e+08      4.149125e+06
# 50%         8.286614e+06      4.203021e+08      8.253011e+06
# 75%         1.242288e+07      6.306964e+08      1.236992e+07
# max         1.655868e+07      8.434227e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      6.484800e+04      6.484800e+04
# mean       4.108230e+07      4.551386e+08
# std        1.117300e+07      2.442563e+08
# min        9.578873e+06      9.046209e+06
# 25%        3.318729e+07      2.433074e+08
# 50%        4.115803e+07      4.574822e+08
# 75%        4.898117e+07      6.668861e+08
# max        7.271475e+07      8.995022e+08
#
# [8 rows x 50 columns]
# Data cleaning completed.
# <class 'pandas.core.frame.DataFrame'>
# Index: 64848 entries, 92 to 149999
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Bearer Id                                 64848 non-null  float64
#  1   Start                                     64848 non-null  object
#  2   Start ms                                  64848 non-null  float64
#  3   End                                       64848 non-null  object
#  4   End ms                                    64848 non-null  float64
#  5   Dur. (ms)                                 64848 non-null  float64
#  6   IMSI                                      64848 non-null  float64
#  7   MSISDN/Number                             64848 non-null  float64
#  8   IMEI                                      64848 non-null  float64
#  9   Last Location Name                        64723 non-null  object
#  10  Avg RTT DL (ms)                           64848 non-null  float64
#  11  Avg RTT UL (ms)                           64848 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   64848 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   64848 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               64848 non-null  float64
#  15  TCP UL Retrans. Vol (Bytes)               64848 non-null  float64
#  16  DL TP < 50 Kbps (%)                       64848 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            64848 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             64848 non-null  float64
#  19  DL TP > 1 Mbps (%)                        64848 non-null  float64
#  20  UL TP < 10 Kbps (%)                       64848 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             64848 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            64848 non-null  float64
#  23  UL TP > 300 Kbps (%)                      64848 non-null  float64
#  24  HTTP DL (Bytes)                           64848 non-null  float64
#  25  HTTP UL (Bytes)                           64848 non-null  float64
#  26  Activity Duration DL (ms)                 64848 non-null  float64
#  27  Activity Duration UL (ms)                 64848 non-null  float64
#  28  Dur. (ms).1                               64848 non-null  float64
#  29  Handset Manufacturer                      64848 non-null  object
#  30  Handset Type                              64848 non-null  object
#  31  Nb of sec with 125000B < Vol DL           64848 non-null  float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     64848 non-null  float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  64848 non-null  float64
#  34  Nb of sec with 37500B < Vol UL            64848 non-null  float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    64848 non-null  float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    64848 non-null  float64
#  37  Nb of sec with Vol DL < 6250B             64848 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             64848 non-null  float64
#  39  Social Media DL (Bytes)                   64848 non-null  float64
#  40  Social Media UL (Bytes)                   64848 non-null  float64
#  41  Google DL (Bytes)                         64848 non-null  float64
#  42  Google UL (Bytes)                         64848 non-null  float64
#  43  Email DL (Bytes)                          64848 non-null  float64
#  44  Email UL (Bytes)                          64848 non-null  float64
#  45  Youtube DL (Bytes)                        64848 non-null  float64
#  46  Youtube UL (Bytes)                        64848 non-null  float64
#  47  Netflix DL (Bytes)                        64848 non-null  float64
#  48  Netflix UL (Bytes)                        64848 non-null  float64
#  49  Gaming DL (Bytes)                         64848 non-null  float64
#  50  Gaming UL (Bytes)                         64848 non-null  float64
#  51  Other DL (Bytes)                          64848 non-null  float64
#  52  Other UL (Bytes)                          64848 non-null  float64
#  53  Total UL (Bytes)                          64848 non-null  float64
#  54  Total DL (Bytes)                          64848 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 27.7+ MB

# %%
df_cleaned.describe()
# Out:
#           Bearer Id      Start ms        End ms      Dur. (ms)          IMSI  \
# count  6.484800e+04  64848.000000  64848.000000   64848.000000  6.484800e+04
# mean   1.002549e+19    499.222474    497.336973  105645.630089  2.082015e+14
# std    2.879922e+18    288.039028    287.548464   53662.668754  3.571748e+08
# min    6.917538e+18      0.000000      0.000000    7284.000000  2.082009e+14
# 25%    7.349883e+18    250.000000    252.000000   65641.000000  2.082014e+14
# 50%    7.349883e+18    498.000000    498.000000   98865.500000  2.082015e+14
# 75%    1.311448e+19    748.000000    749.000000  145618.750000  2.082018e+14
# max    1.318654e+19    999.000000    999.000000  244900.000000  2.082022e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   6.484800e+04  6.484800e+04     64848.000000     64848.000000
# mean    3.365623e+10  4.200191e+13        62.098806         8.419444
# std     2.370101e+07  1.721620e+13        38.145449         7.461515
# min     3.360171e+10  4.400152e+11         0.000000         0.000000
# 25%     3.364403e+10  3.540531e+13        30.000000         2.000000
# 50%     3.366142e+10  3.565611e+13        45.000000         5.000000
# 75%     3.366807e+10  3.589791e+13       109.795706        17.662883
# max     3.370000e+10  9.900120e+13       221.000000        39.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count             64848.000000  ...        6.484800e+04        6.484800e+04
# mean                917.953121  ...        1.159000e+07        1.101830e+07
# std                4074.999617  ...        6.706067e+06        6.323092e+06
# min                   0.000000  ...        5.300000e+01        1.610000e+02
# 25%                  34.000000  ...        5.802918e+06        5.561978e+06
# 50%                  46.000000  ...        1.152636e+07        1.104523e+07
# 75%                  62.000000  ...        1.738991e+07        1.651168e+07
# max               49058.000000  ...        2.325881e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        6.484800e+04        6.484800e+04       6.484800e+04
# mean         1.161094e+07        1.097372e+07       4.225990e+08
# std          6.728007e+06        6.351951e+06       2.440674e+08
# min          4.200000e+01        2.260000e+02       2.516000e+03
# 25%          5.777664e+06        5.461299e+06       2.109423e+08
# 50%          1.164990e+07        1.095161e+07       4.248652e+08
# 75%          1.746121e+07        1.648105e+07       6.343947e+08
# max          2.325815e+07        2.201184e+07       8.434260e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       6.484800e+04      6.484800e+04      6.484800e+04
# mean        8.279814e+06      4.201536e+08      8.255999e+06
# std         4.778230e+06      2.436100e+08      4.764368e+06
# min         1.130000e+02      3.290000e+03      1.480000e+02
# 25%         4.117991e+06      2.093789e+08      4.149125e+06
# 50%         8.286614e+06      4.203021e+08      8.253011e+06
# 75%         1.242288e+07      6.306964e+08      1.236992e+07
# max         1.655868e+07      8.434227e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      6.484800e+04      6.484800e+04
# mean       4.108230e+07      4.551386e+08
# std        1.117300e+07      2.442563e+08
# min        9.578873e+06      9.046209e+06
# 25%        3.318729e+07      2.433074e+08
# 50%        4.115803e+07      4.574822e+08
# 75%        4.898117e+07      6.668861e+08
# max        7.271475e+07      8.995022e+08
#
# [8 rows x 50 columns]

# %%
df_cleaned.isnull().sum()
# Out:
# Bearer Id                                     0
# Start                                         0
# Start ms                                      0
# End                                           0
# End ms                                        0
# Dur. (ms)                                     0
# IMSI                                          0
# MSISDN/Number                                 0
# IMEI                                          0
# Last Location Name                          125
# Avg RTT DL (ms)                               0
# Avg RTT UL (ms)                               0
# Avg Bearer TP DL (kbps)                       0
# Avg Bearer TP UL (kbps)                       0
# TCP DL Retrans. Vol (Bytes)                   0
# TCP UL Retrans. Vol (Bytes)                   0
# DL TP < 50 Kbps (%)                           0
# 50 Kbps < DL TP < 250 Kbps (%)                0
# 250 Kbps < DL TP < 1 Mbps (%)                 0
# DL TP > 1 Mbps (%)                            0
# UL TP < 10 Kbps (%)                           0
# 10 Kbps < UL TP < 50 Kbps (%)                 0
# 50 Kbps < UL TP < 300 Kbps (%)                0
# UL TP > 300 Kbps (%)                          0
# HTTP DL (Bytes)                               0
# HTTP UL (Bytes)                               0
# Activity Duration DL (ms)                     0
# Activity Duration UL (ms)                     0
# Dur. (ms).1                                   0
# Handset Manufacturer                          0
# Handset Type                                  0
# Nb of sec with 125000B < Vol DL               0
# Nb of sec with 1250B < Vol UL < 6250B         0
# Nb of sec with 31250B < Vol DL < 125000B      0
# Nb of sec with 37500B < Vol UL                0
# Nb of sec with 6250B < Vol DL < 31250B        0
# Nb of sec with 6250B < Vol UL < 37500B        0
# Nb of sec with Vol DL < 6250B                 0
# Nb of sec with Vol UL < 1250B                 0
# Social Media DL (Bytes)                       0
# Social Media UL (Bytes)                       0
# Google DL (Bytes)                             0
# Google UL (Bytes)                             0
# Email DL (Bytes)                              0
# Email UL (Bytes)                              0
# Youtube DL (Bytes)                            0
# Youtube UL (Bytes)                            0
# Netflix DL (Bytes)                            0
# Netflix UL (Bytes)                            0
# Gaming DL (Bytes)                             0
# Gaming UL (Bytes)                             0
# Other DL (Bytes)                              0
# Other UL (Bytes)                              0
# Total UL (Bytes)                              0
# Total DL (Bytes)                              0
# dtype: int64

# %%
df_transformed =df_cleaned
# df_transformed = transform_data(df)
# df = df_transformed
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64848 entries, 92 to 149999
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Bearer Id                                 64848 non-null  float64
#  1   Start                                     64848 non-null  object
#  2   Start ms                                  64848 non-null  float64
#  3   End                                       64848 non-null  object
#  4   End ms                                    64848 non-null  float64
#  5   Dur. (ms)                                 64848 non-null  float64
#  6   IMSI                                      64848 non-null  float64
#  7   MSISDN/Number                             64848 non-null  float64
#  8   IMEI                                      64848 non-null  float64
#  9   Last Location Name                        64723 non-null  object
#  10  Avg RTT DL (ms)                           64848 non-null  float64
#  11  Avg RTT UL (ms)                           64848 non-null  float64
#  12  Avg Bearer TP DL (kbps)                   64848 non-null  float64
#  13  Avg Bearer TP UL (kbps)                   64848 non-null  float64
#  14  TCP DL Retrans. Vol (Bytes)               64848 non-null  float64
#  15  TCP UL Retrans. Vol (Bytes)               64848 non-null  float64
#  16  DL TP < 50 Kbps (%)                       64848 non-null  float64
#  17  50 Kbps < DL TP < 250 Kbps (%)            64848 non-null  float64
#  18  250 Kbps < DL TP < 1 Mbps (%)             64848 non-null  float64
#  19  DL TP > 1 Mbps (%)                        64848 non-null  float64
#  20  UL TP < 10 Kbps (%)                       64848 non-null  float64
#  21  10 Kbps < UL TP < 50 Kbps (%)             64848 non-null  float64
#  22  50 Kbps < UL TP < 300 Kbps (%)            64848 non-null  float64
#  23  UL TP > 300 Kbps (%)                      64848 non-null  float64
#  24  HTTP DL (Bytes)                           64848 non-null  float64
#  25  HTTP UL (Bytes)                           64848 non-null  float64
#  26  Activity Duration DL (ms)                 64848 non-null  float64
#  27  Activity Duration UL (ms)                 64848 non-null  float64
#  28  Dur. (ms).1                               64848 non-null  float64
#  29  Handset Manufacturer                      64848 non-null  object
#  30  Handset Type                              64848 non-null  object
#  31  Nb of sec with 125000B < Vol DL           64848 non-null  float64
#  32  Nb of sec with 1250B < Vol UL < 6250B     64848 non-null  float64
#  33  Nb of sec with 31250B < Vol DL < 125000B  64848 non-null  float64
#  34  Nb of sec with 37500B < Vol UL            64848 non-null  float64
#  35  Nb of sec with 6250B < Vol DL < 31250B    64848 non-null  float64
#  36  Nb of sec with 6250B < Vol UL < 37500B    64848 non-null  float64
#  37  Nb of sec with Vol DL < 6250B             64848 non-null  float64
#  38  Nb of sec with Vol UL < 1250B             64848 non-null  float64
#  39  Social Media DL (Bytes)                   64848 non-null  float64
#  40  Social Media UL (Bytes)                   64848 non-null  float64
#  41  Google DL (Bytes)                         64848 non-null  float64
#  42  Google UL (Bytes)                         64848 non-null  float64
#  43  Email DL (Bytes)                          64848 non-null  float64
#  44  Email UL (Bytes)                          64848 non-null  float64
#  45  Youtube DL (Bytes)                        64848 non-null  float64
#  46  Youtube UL (Bytes)                        64848 non-null  float64
#  47  Netflix DL (Bytes)                        64848 non-null  float64
#  48  Netflix UL (Bytes)                        64848 non-null  float64
#  49  Gaming DL (Bytes)                         64848 non-null  float64
#  50  Gaming UL (Bytes)                         64848 non-null  float64
#  51  Other DL (Bytes)                          64848 non-null  float64
#  52  Other UL (Bytes)                          64848 non-null  float64
#  53  Total UL (Bytes)                          64848 non-null  float64
#  54  Total DL (Bytes)                          64848 non-null  float64
# dtypes: float64(50), object(5)
# memory usage: 27.7+ MB

# %%
df_transformed.describe()
# Out:
#           Bearer Id      Start ms        End ms      Dur. (ms)          IMSI  \
# count  6.484800e+04  64848.000000  64848.000000   64848.000000  6.484800e+04
# mean   1.002549e+19    499.222474    497.336973  105645.630089  2.082015e+14
# std    2.879922e+18    288.039028    287.548464   53662.668754  3.571748e+08
# min    6.917538e+18      0.000000      0.000000    7284.000000  2.082009e+14
# 25%    7.349883e+18    250.000000    252.000000   65641.000000  2.082014e+14
# 50%    7.349883e+18    498.000000    498.000000   98865.500000  2.082015e+14
# 75%    1.311448e+19    748.000000    749.000000  145618.750000  2.082018e+14
# max    1.318654e+19    999.000000    999.000000  244900.000000  2.082022e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   6.484800e+04  6.484800e+04     64848.000000     64848.000000
# mean    3.365623e+10  4.200191e+13        62.098806         8.419444
# std     2.370101e+07  1.721620e+13        38.145449         7.461515
# min     3.360171e+10  4.400152e+11         0.000000         0.000000
# 25%     3.364403e+10  3.540531e+13        30.000000         2.000000
# 50%     3.366142e+10  3.565611e+13        45.000000         5.000000
# 75%     3.366807e+10  3.589791e+13       109.795706        17.662883
# max     3.370000e+10  9.900120e+13       221.000000        39.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count             64848.000000  ...        6.484800e+04        6.484800e+04
# mean                917.953121  ...        1.159000e+07        1.101830e+07
# std                4074.999617  ...        6.706067e+06        6.323092e+06
# min                   0.000000  ...        5.300000e+01        1.610000e+02
# 25%                  34.000000  ...        5.802918e+06        5.561978e+06
# 50%                  46.000000  ...        1.152636e+07        1.104523e+07
# 75%                  62.000000  ...        1.738991e+07        1.651168e+07
# max               49058.000000  ...        2.325881e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        6.484800e+04        6.484800e+04       6.484800e+04
# mean         1.161094e+07        1.097372e+07       4.225990e+08
# std          6.728007e+06        6.351951e+06       2.440674e+08
# min          4.200000e+01        2.260000e+02       2.516000e+03
# 25%          5.777664e+06        5.461299e+06       2.109423e+08
# 50%          1.164990e+07        1.095161e+07       4.248652e+08
# 75%          1.746121e+07        1.648105e+07       6.343947e+08
# max          2.325815e+07        2.201184e+07       8.434260e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       6.484800e+04      6.484800e+04      6.484800e+04
# mean        8.279814e+06      4.201536e+08      8.255999e+06
# std         4.778230e+06      2.436100e+08      4.764368e+06
# min         1.130000e+02      3.290000e+03      1.480000e+02
# 25%         4.117991e+06      2.093789e+08      4.149125e+06
# 50%         8.286614e+06      4.203021e+08      8.253011e+06
# 75%         1.242288e+07      6.306964e+08      1.236992e+07
# max         1.655868e+07      8.434227e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      6.484800e+04      6.484800e+04
# mean       4.108230e+07      4.551386e+08
# std        1.117300e+07      2.442563e+08
# min        9.578873e+06      9.046209e+06
# 25%        3.318729e+07      2.433074e+08
# 50%        4.115803e+07      4.574822e+08
# 75%        4.898117e+07      6.668861e+08
# max        7.271475e+07      8.995022e+08
#
# [8 rows x 50 columns]

# %%
df_transformed.isnull().sum()
# Out:
# Bearer Id                                     0
# Start                                         0
# Start ms                                      0
# End                                           0
# End ms                                        0
# Dur. (ms)                                     0
# IMSI                                          0
# MSISDN/Number                                 0
# IMEI                                          0
# Last Location Name                          125
# Avg RTT DL (ms)                               0
# Avg RTT UL (ms)                               0
# Avg Bearer TP DL (kbps)                       0
# Avg Bearer TP UL (kbps)                       0
# TCP DL Retrans. Vol (Bytes)                   0
# TCP UL Retrans. Vol (Bytes)                   0
# DL TP < 50 Kbps (%)                           0
# 50 Kbps < DL TP < 250 Kbps (%)                0
# 250 Kbps < DL TP < 1 Mbps (%)                 0
# DL TP > 1 Mbps (%)                            0
# UL TP < 10 Kbps (%)                           0
# 10 Kbps < UL TP < 50 Kbps (%)                 0
# 50 Kbps < UL TP < 300 Kbps (%)                0
# UL TP > 300 Kbps (%)                          0
# HTTP DL (Bytes)                               0
# HTTP UL (Bytes)                               0
# Activity Duration DL (ms)                     0
# Activity Duration UL (ms)                     0
# Dur. (ms).1                                   0
# Handset Manufacturer                          0
# Handset Type                                  0
# Nb of sec with 125000B < Vol DL               0
# Nb of sec with 1250B < Vol UL < 6250B         0
# Nb of sec with 31250B < Vol DL < 125000B      0
# Nb of sec with 37500B < Vol UL                0
# Nb of sec with 6250B < Vol DL < 31250B        0
# Nb of sec with 6250B < Vol UL < 37500B        0
# Nb of sec with Vol DL < 6250B                 0
# Nb of sec with Vol UL < 1250B                 0
# Social Media DL (Bytes)                       0
# Social Media UL (Bytes)                       0
# Google DL (Bytes)                             0
# Google UL (Bytes)                             0
# Email DL (Bytes)                              0
# Email UL (Bytes)                              0
# Youtube DL (Bytes)                            0
# Youtube UL (Bytes)                            0
# Netflix DL (Bytes)                            0
# Netflix UL (Bytes)                            0
# Gaming DL (Bytes)                             0
# Gaming UL (Bytes)                             0
# Other DL (Bytes)                              0
# Other UL (Bytes)                              0
# Total UL (Bytes)                              0
# Total DL (Bytes)                              0
# dtype: int64

# %%
# Top 10 handsets used by customers
# top_10_handsets = df['Handset Type'].value_counts().head(10)
top_10_handsets = get_top_10_handsets()
top_10_handsets
# Out:
#                         handset  usagecount
# 0              Huawei B528S-23A       19752
# 1       Apple iPhone 6S (A1688)        9419
# 2        Apple iPhone 6 (A1586)        9023
# 3                     undefined        8987
# 4        Apple iPhone 7 (A1778)        6326
# 5       Apple iPhone Se (A1723)        5187
# 6        Apple iPhone 8 (A1905)        4993
# 7       Apple iPhone Xr (A2105)        4568
# 8  Samsung Galaxy S8 (Sm-G950F)        4520
# 9        Apple iPhone X (A1901)        3813

# %%
# Top 3 handset manufacturers
top_3_manufacturers = get_top_3_manufacturers()
# top_3_manufacturers = df['Handset Manufacturer'].value_counts().head(3)
top_3_manufacturers
# Out:
#   Handset Manufacturer  usagecount
# 0                Apple       59565
# 1              Samsung       40839
# 2               Huawei       34423

# %%
# Identify the top 5 handset per top 3 handset manufacturer
# top_5_handsets_per_manufacturer = (
#         df[df['Handset Manufacturer'].isin(top_3_manufacturers.index)]
#         .groupby(['Handset Manufacturer', 'Handset Type'])
#         .size()
#         .reset_index(name='usage_count')
#         .sort_values(['Handset Manufacturer', 'usage_count'], ascending=[True, False])
#         .groupby('Handset Manufacturer')
#         .head(5)
# )
# top_5_handsets_per_manufacturer.head(15)
top_5_handsets_per_manufacturer = get_top_handsets_by_manufacturers()
top_5_handsets_per_manufacturer
# Out:
#     Handset Manufacturer                             Handset Type  usagecount
# 0                  Apple                  Apple iPhone 6S (A1688)        9419
# 1                  Apple                   Apple iPhone 6 (A1586)        9023
# 2                  Apple                   Apple iPhone 7 (A1778)        6326
# 3                  Apple                  Apple iPhone Se (A1723)        5187
# 4                  Apple                   Apple iPhone 8 (A1905)        4993
# ..                   ...                                      ...         ...
# 420              Samsung        Samsung Galaxy S4 Active Gt-I9295           1
# 421              Samsung  Samsung Galaxy Mobile (E.G. A3Lschi535)           1
# 422              Samsung  Samsung Galaxy J1 Mini Prime (Sm-J106B)           1
# 423              Samsung                         Samsung Gt-B5510           1
# 424              Samsung         Samsung Galaxy Note 8 (Sm-N9500)           1
#
# [425 rows x 3 columns]

# %%
unique_imsi_count = get_unique_imsi_count()
unique_imsi_count
# Out:
#    unique_imsi_count
# 0             107265

# %%
average_duration = get_average_duration()
average_duration
# Out:
#    average_duration
# 0     104608.560347

# %%
total_data_usage = get_total_data_usage()
total_data_usage
# Out:
#            IMSI  total_ul_bytes  total_dl_bytes
# 0           NaN    2.350613e+10    2.580162e+11
# 1  2.082017e+14    6.894830e+08    8.156743e+09
# 2  2.082021e+14    7.034786e+08    7.811295e+09
# 3  2.082010e+14    7.295774e+08    7.770043e+09
# 4  2.082010e+14    5.815688e+08    7.309542e+09
# 5  2.082014e+14    6.696507e+08    7.301517e+09
# 6  2.082019e+14    6.242603e+08    7.081602e+09
# 7  2.082014e+14    4.050610e+08    6.903440e+09
# 8  2.082003e+14    5.215189e+08    6.610852e+09
# 9  2.082017e+14    4.712445e+08    6.400774e+09

# %%
# Average duration by Last Location Name
# avg_duration_by_location = df.groupby('Last Location Name')['Dur. (ms)'].mean().reset_index().sort_values(by='Dur. (ms)', ascending=False)
avg_duration_by_location = get_avg_duration_by_location()
avg_duration_by_location
# Out:
#          Last Location Name  avgduration
# 0                   T53539A    1177517.0
# 1      CELL_208_20_520166_7    1134225.0
# 2                   D20985B    1038128.0
# 3                   D94074C    1010097.0
# 4                   T76656C     985972.0
# ...                     ...          ...
# 45543               G92776B       7327.0
# 45544               G52206C       7326.0
# 45545               G92604C       7267.0
# 45546               G30104B       7258.0
# 45547               G30532C       7146.0
#
# [45548 rows x 2 columns]

# %%
# Average duration by Handset Manufacturer
# avg_duration_by_manufacturer = df.groupby('Handset Manufacturer')['Dur. (ms)'].mean().reset_index().sort_values(by='Dur. (ms)', ascending=False)
avg_duration_by_manufacturer = get_avg_duration_by_manufacturer()
avg_duration_by_manufacturer
# Out:
#                             Handset Manufacturer    avgduration
# 0              Quectel Wireless Solutions Co Ltd  610571.333333
# 1                    Tp-Link Technologies Co Ltd  209800.395349
# 2                           Pt. Arga Mas Lestari  172796.000000
# 3                                            Zte  141201.827225
# 4                                      undefined  127134.754868
# ..                                           ...            ...
# 166     Shanghai Chengyu Media Technology Co Ltd   17774.000000
# 167                          Alif Communications   16617.000000
# 168  Shenzhen New Chabridge Communication Co Ltd   16180.000000
# 169             Casper Bilgisayar Sistemleri A.S   15033.000000
# 170            Shenzhen Diadem Technology Co Ltd   10977.000000
#
# [171 rows x 2 columns]

# %%
# Average duration by Handset Type
# avg_duration_by_handset_type = df.groupby('Handset Type')['Dur. (ms)'].mean().reset_index().sort_values(by='Dur. (ms)', ascending=False)
avg_duration_by_handset_type = get_avg_duration_by_handset_type()
avg_duration_by_handset_type
# Out:
#                                    Handset Type    avgduration
# 0              Quectel Wireless. Quectel Ec25-E  877385.000000
# 1              Quectel Wireless. Quectel Ec21-E  869844.000000
# 2                   Tp-Link Technolo. Tl-Mr6400  445733.125000
# 3                               Huawei B593S-22  254706.600000
# 4                       Apple iPhone Xr (A2106)  240221.166667
# ...                                         ...            ...
# 1392    Sony Mobile Comm. Sony C5303 -Xperia Sp    8790.000000
# 1393  Tct Mobile Suzho. Alcatel Onetouch Pop S7    8700.000000
# 1394                Archos Sa 50B Cobalt (Lite)    8557.000000
# 1395                           Acer Liquid Z530    8266.000000
# 1396                 Xiaomi Communica. M1901F7G    7434.000000
#
# [1397 rows x 2 columns]

# %%
fig = plot_data(df, 'histogram', x='Avg RTT DL (ms)', title='Histogram of Avg RTT DL (ms)', xlabel='Values', ylabel='Frequency')
plt.show(fig)

# %%
# Boxplot
fig = plot_data(df, 'boxplot', x='Avg RTT DL (ms)', title='Box Plot of Avg RTT DL (ms)', xlabel='Values', ylabel='Frequency')
plt.show(fig)

# %%
# Violin plot
fig = plot_data(df, 'violinplot', x='Avg RTT DL (ms)', title='Violin Plot of Avg RTT DL (ms)', xlabel='Values', ylabel='Frequency')
plt.show(fig)

# %%
# Add total data volume column
df['total_data_volume'] = df['Total DL (Bytes)'] + df['Total UL (Bytes)']

# Melt the application columns into rows
app_columns = ['Google DL (Bytes)', 'Google UL (Bytes)', 
               'Email DL (Bytes)', 'Email UL (Bytes)','Youtube DL (Bytes)', 
               'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)']


df_long = melt_dataframe(df, app_columns)
df_long.head(5)
# Out:
#       Bearer Id  Dur. (ms)  total_data_volume  Total DL (Bytes)  \
# 0  1.311448e+19   243504.0        599743023.0       556406594.0
# 1  1.311448e+19   236570.0        798245704.0       757526492.0
# 2  1.311448e+19   231780.0        192095344.0       139043208.0
# 3  1.311448e+19   230839.0        359872820.0       329159454.0
# 4  7.349883e+18   238915.0        604428354.0       546747900.0
#
#    Total UL (Bytes)           app_name  data_volume
# 0        43336429.0  Google DL (Bytes)    6639041.0
# 1        40719212.0  Google DL (Bytes)    4259111.0
# 2        53052136.0  Google DL (Bytes)     962332.0
# 3        30713366.0  Google DL (Bytes)    8477509.0
# 4        57680454.0  Google DL (Bytes)     721187.0

# %%
# Aggregate per user and application
agg_df = get_aggregate_dataframe(df_long)
agg_df.head(5)
# Out:
#       Bearer Id           app_name  number_of_sessions  \
# 0  6.917538e+18   Email DL (Bytes)                   1
# 1  6.917538e+18   Email UL (Bytes)                   1
# 2  6.917538e+18  Gaming DL (Bytes)                   1
# 3  6.917538e+18  Gaming UL (Bytes)                   1
# 4  6.917538e+18  Google DL (Bytes)                   1
#
#    total_session_duration  total_download_data  total_upload_data  \
# 0                 21489.0          709549265.0         38693596.0
# 1                 21489.0          709549265.0         38693596.0
# 2                 21489.0          709549265.0         38693596.0
# 3                 21489.0          709549265.0         38693596.0
# 4                 21489.0          709549265.0         38693596.0
#
#    total_data_volume
# 0           446376.0
# 1           525108.0
# 2        673282567.0
# 3          2670856.0
# 4          3605446.0

# %%
# Compute dispersion parameters for each quantitative variable
numeric_dataframe = df.select_dtypes(include='number')
dispersion_summary = get_dispersion_summary(numeric_dataframe)
dispersion_summary
# Out:
#                                                   Mean        Median  \
# Bearer Id                                 1.002549e+19  7.349883e+18
# Start ms                                  4.992225e+02  4.980000e+02
# End ms                                    4.973370e+02  4.980000e+02
# Dur. (ms)                                 1.056456e+05  9.886550e+04
# IMSI                                      2.082015e+14  2.082015e+14
# MSISDN/Number                             3.365623e+10  3.366142e+10
# IMEI                                      4.200191e+13  3.565611e+13
# Avg RTT DL (ms)                           6.209881e+01  4.500000e+01
# Avg RTT UL (ms)                           8.419444e+00  5.000000e+00
# Avg Bearer TP DL (kbps)                   9.179531e+02  4.600000e+01
# Avg Bearer TP UL (kbps)                   8.821336e+01  5.100000e+01
# TCP DL Retrans. Vol (Bytes)               1.872820e+07  2.080991e+07
# TCP UL Retrans. Vol (Bytes)               7.122846e+05  7.596587e+05
# DL TP < 50 Kbps (%)                       9.958586e+01  1.000000e+02
# 50 Kbps < DL TP < 250 Kbps (%)            1.969861e-01  0.000000e+00
# 250 Kbps < DL TP < 1 Mbps (%)             4.171122e-02  0.000000e+00
# DL TP > 1 Mbps (%)                        2.248974e-02  0.000000e+00
# UL TP < 10 Kbps (%)                       9.993735e+01  1.000000e+02
# 10 Kbps < UL TP < 50 Kbps (%)             0.000000e+00  0.000000e+00
# 50 Kbps < UL TP < 300 Kbps (%)            0.000000e+00  0.000000e+00
# UL TP > 300 Kbps (%)                      0.000000e+00  0.000000e+00
# HTTP DL (Bytes)                           9.747445e+07  1.144710e+08
# HTTP UL (Bytes)                           2.765331e+06  3.242301e+06
# Activity Duration DL (ms)                 4.187404e+04  2.097350e+04
# Activity Duration UL (ms)                 4.535189e+04  2.745500e+04
# Dur. (ms).1                               1.056461e+08  9.886607e+07
# Nb of sec with 125000B < Vol DL           9.449818e+02  9.897000e+02
# Nb of sec with 1250B < Vol UL < 6250B     3.193773e+02  3.404344e+02
# Nb of sec with 31250B < Vol DL < 125000B  7.583692e+02  8.108374e+02
# Nb of sec with 37500B < Vol UL            1.492571e+02  1.492571e+02
# Nb of sec with 6250B < Vol DL < 31250B    8.710728e+02  9.654648e+02
# Nb of sec with 6250B < Vol UL < 37500B    1.413048e+02  1.413048e+02
# Nb of sec with Vol DL < 6250B             2.858070e+02  1.090000e+02
# Nb of sec with Vol UL < 1250B             2.135704e+02  1.260000e+02
# Social Media DL (Bytes)                   1.796867e+06  1.791842e+06
# Social Media UL (Bytes)                   3.294287e+04  3.294850e+04
# Google DL (Bytes)                         5.751646e+06  5.754888e+06
# Google UL (Bytes)                         2.055188e+06  2.043446e+06
# Email DL (Bytes)                          1.790156e+06  1.793559e+06
# Email UL (Bytes)                          4.663337e+05  4.639465e+05
# Youtube DL (Bytes)                        1.159000e+07  1.152636e+07
# Youtube UL (Bytes)                        1.101830e+07  1.104523e+07
# Netflix DL (Bytes)                        1.161094e+07  1.164990e+07
# Netflix UL (Bytes)                        1.097372e+07  1.095161e+07
# Gaming DL (Bytes)                         4.225990e+08  4.248652e+08
# Gaming UL (Bytes)                         8.279814e+06  8.286614e+06
# Other DL (Bytes)                          4.201536e+08  4.203021e+08
# Other UL (Bytes)                          8.255999e+06  8.253011e+06
# Total UL (Bytes)                          4.108230e+07  4.115803e+07
# Total DL (Bytes)                          4.551386e+08  4.574822e+08
# total_data_volume                         4.962209e+08  4.983127e+08
#
#                                                  Range      Variance  \
# Bearer Id                                 6.269004e+18  8.293952e+36
# Start ms                                  9.990000e+02  8.296648e+04
# End ms                                    9.990000e+02  8.268412e+04
# Dur. (ms)                                 2.376160e+05  2.879682e+09
# IMSI                                      1.351616e+09  1.275738e+17
# MSISDN/Number                             9.828724e+07  5.617380e+14
# IMEI                                      9.856119e+13  2.963975e+26
# Avg RTT DL (ms)                           2.210000e+02  1.455075e+03
# Avg RTT UL (ms)                           3.900000e+01  5.567421e+01
# Avg Bearer TP DL (kbps)                   4.905800e+04  1.660562e+07
# Avg Bearer TP UL (kbps)                   1.046000e+03  1.817007e+04
# TCP DL Retrans. Vol (Bytes)               4.896874e+07  3.868460e+13
# TCP UL Retrans. Vol (Bytes)               1.638203e+06  3.331014e+10
# DL TP < 50 Kbps (%)                       1.500000e+01  2.318722e+00
# 50 Kbps < DL TP < 250 Kbps (%)            1.000000e+01  8.042913e-01
# 250 Kbps < DL TP < 1 Mbps (%)             2.000000e+00  6.333249e-02
# DL TP > 1 Mbps (%)                        2.000000e+00  3.310395e-02
# UL TP < 10 Kbps (%)                       1.000000e+00  5.872956e-02
# 10 Kbps < UL TP < 50 Kbps (%)             0.000000e+00  0.000000e+00
# 50 Kbps < UL TP < 300 Kbps (%)            0.000000e+00  0.000000e+00
# UL TP > 300 Kbps (%)                      0.000000e+00  0.000000e+00
# HTTP DL (Bytes)                           1.555732e+08  1.646086e+15
# HTTP UL (Bytes)                           7.266502e+06  1.292894e+12
# Activity Duration DL (ms)                 1.665309e+06  1.066370e+10
# Activity Duration UL (ms)                 1.463259e+06  8.229240e+09
# Dur. (ms).1                               2.376152e+08  2.879682e+15
# Nb of sec with 125000B < Vol DL           9.887000e+02  4.188004e+04
# Nb of sec with 1250B < Vol UL < 6250B     3.394344e+02  6.635341e+03
# Nb of sec with 31250B < Vol DL < 125000B  8.098374e+02  3.921894e+04
# Nb of sec with 37500B < Vol UL            0.000000e+00  8.078060e-28
# Nb of sec with 6250B < Vol DL < 31250B    9.644648e+02  8.009109e+04
# Nb of sec with 6250B < Vol UL < 37500B    0.000000e+00  3.231224e-27
# Nb of sec with Vol DL < 6250B             6.771000e+03  5.510091e+05
# Nb of sec with Vol UL < 1250B             6.236000e+03  1.572999e+05
# Social Media DL (Bytes)                   3.585917e+06  1.072882e+12
# Social Media UL (Bytes)                   6.587000e+04  3.628450e+08
# Google DL (Bytes)                         1.146251e+07  1.098069e+13
# Google UL (Bytes)                         4.121238e+06  1.409039e+12
# Email DL (Bytes)                          3.586049e+06  1.072410e+12
# Email UL (Bytes)                          9.364110e+05  7.272644e+10
# Youtube DL (Bytes)                        2.325876e+07  4.497134e+13
# Youtube UL (Bytes)                        2.201180e+07  3.998149e+13
# Netflix DL (Bytes)                        2.325811e+07  4.526608e+13
# Netflix UL (Bytes)                        2.201161e+07  4.034728e+13
# Gaming DL (Bytes)                         8.434235e+08  5.956887e+16
# Gaming UL (Bytes)                         1.655857e+07  2.283148e+13
# Other DL (Bytes)                          8.434194e+08  5.934585e+16
# Other UL (Bytes)                          1.655867e+07  2.269920e+13
# Total UL (Bytes)                          6.313588e+07  1.248359e+14
# Total DL (Bytes)                          8.904560e+08  5.966116e+16
# total_data_volume                         9.218046e+08  5.978682e+16
#
#                                                Std Dev           IQR
# Bearer Id                                 2.879922e+18  5.764600e+18
# Start ms                                  2.880390e+02  4.980000e+02
# End ms                                    2.875485e+02  4.970000e+02
# Dur. (ms)                                 5.366267e+04  7.997775e+04
# IMSI                                      3.571748e+08  3.692350e+08
# MSISDN/Number                             2.370101e+07  2.404035e+07
# IMEI                                      1.721620e+13  4.925985e+11
# Avg RTT DL (ms)                           3.814545e+01  7.979571e+01
# Avg RTT UL (ms)                           7.461515e+00  1.566288e+01
# Avg Bearer TP DL (kbps)                   4.075000e+03  2.800000e+01
# Avg Bearer TP UL (kbps)                   1.347964e+02  1.600000e+01
# TCP DL Retrans. Vol (Bytes)               6.219694e+06  0.000000e+00
# TCP UL Retrans. Vol (Bytes)               1.825107e+05  0.000000e+00
# DL TP < 50 Kbps (%)                       1.522735e+00  0.000000e+00
# 50 Kbps < DL TP < 250 Kbps (%)            8.968229e-01  0.000000e+00
# 250 Kbps < DL TP < 1 Mbps (%)             2.516595e-01  0.000000e+00
# DL TP > 1 Mbps (%)                        1.819449e-01  0.000000e+00
# UL TP < 10 Kbps (%)                       2.423418e-01  0.000000e+00
# 10 Kbps < UL TP < 50 Kbps (%)             0.000000e+00  0.000000e+00
# 50 Kbps < UL TP < 300 Kbps (%)            0.000000e+00  0.000000e+00
# UL TP > 300 Kbps (%)                      0.000000e+00  0.000000e+00
# HTTP DL (Bytes)                           4.057199e+07  0.000000e+00
# HTTP UL (Bytes)                           1.137055e+06  0.000000e+00
# Activity Duration DL (ms)                 1.032652e+05  2.786750e+04
# Activity Duration UL (ms)                 9.071516e+04  2.867425e+04
# Dur. (ms).1                               5.366267e+07  7.997777e+07
# Nb of sec with 125000B < Vol DL           2.046461e+02  0.000000e+00
# Nb of sec with 1250B < Vol UL < 6250B     8.145760e+01  0.000000e+00
# Nb of sec with 31250B < Vol DL < 125000B  1.980377e+02  0.000000e+00
# Nb of sec with 37500B < Vol UL            2.842193e-14  0.000000e+00
# Nb of sec with 6250B < Vol DL < 31250B    2.830037e+02  0.000000e+00
# Nb of sec with 6250B < Vol UL < 37500B    5.684386e-14  0.000000e+00
# Nb of sec with Vol DL < 6250B             7.422999e+02  1.260000e+02
# Nb of sec with Vol UL < 1250B             3.966105e+02  1.170000e+02
# Social Media DL (Bytes)                   1.035800e+06  1.797706e+06
# Social Media UL (Bytes)                   1.904849e+04  3.306725e+04
# Google DL (Bytes)                         3.313712e+06  5.734751e+06
# Google UL (Bytes)                         1.187029e+06  2.054688e+06
# Email DL (Bytes)                          1.035572e+06  1.794459e+06
# Email UL (Bytes)                          2.696784e+05  4.655002e+05
# Youtube DL (Bytes)                        6.706067e+06  1.158699e+07
# Youtube UL (Bytes)                        6.323092e+06  1.094970e+07
# Netflix DL (Bytes)                        6.728007e+06  1.168354e+07
# Netflix UL (Bytes)                        6.351951e+06  1.101975e+07
# Gaming DL (Bytes)                         2.440674e+08  4.234524e+08
# Gaming UL (Bytes)                         4.778230e+06  8.304894e+06
# Other DL (Bytes)                          2.436100e+08  4.213175e+08
# Other UL (Bytes)                          4.764368e+06  8.220790e+06
# Total UL (Bytes)                          1.117300e+07  1.579388e+07
# Total DL (Bytes)                          2.442563e+08  4.235787e+08
# total_data_volume                         2.445134e+08  4.226706e+08

# %%
fig = plot_data(df, 'histogram', x='Total UL (Bytes)', title='Histogram of Total UL (Bytes)', xlabel='Values', ylabel='Frequency')
plt.show(fig)

# %%
fig = plot_data(df, 'boxplot', x='Total UL (Bytes)', title='Box Plot of Total UL (Bytes)', ylabel='Values')
plt.show(fig)

# %%
fig = plot_data(df, 'kde', x='Total UL (Bytes)', title='Density Plot of Total UL (Bytes)', xlabel='Total UL (Bytes)')
plt.show(fig)
# Out:
# c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\notebooks\..\scripts\vizualize.py:68: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dataframe[x], shade=kwargs.get('shade', True), ax=ax)

# %%
fig = plot_data(df, 'histogram', x='Dur. (ms)', bins=30, kde=True, title='Distribution of Call Duration', xlabel='Duration (ms)', ylabel='Frequency')
plt.show(fig)

# %%
fig = plot_data(df, 'bar', x='Handset Type', title='Bar Plot of Handset Type', xlabel='Handset Type', ylabel='Frequency')
plt.show(fig)

# %%
df['total_data_volume'] = df['Total DL (Bytes)'] + df['Total UL (Bytes)']
get_total_data_usage_by_application('Google').describe().head(5)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# UndefinedColumn: column "MSISDN" does not exist
# LINE 3:                     "MSISDN" AS UserID,
#                             ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[33], line 2
#       1 df['total_data_volume'] = df['Total DL (Bytes)'] + df['Total UL (Bytes)']
# ----> 2 get_total_data_usage_by_application('Google').describe().head(5)
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\notebooks\..\scripts\sql_queries.py:147, in get_total_data_usage_by_application(application)
#     138 def get_total_data_usage_by_application(application):
#     139     query = f"""
#     140                 SELECT
#     141                     "MSISDN" AS UserID,
#    (...)
#     145                 ORDER BY TotalDataVolume DESC;
#     146             """
# --> 147     return execute_queries(query).groupby('ApplicationDataVolume')['TotalDataVolume']
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\notebooks\..\scripts\sql_queries.py:16, in execute_queries(query)
#      14 def execute_queries(query):
#      15     engine = create_engine(f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}")
# ---> 16     return pd.read_sql_query(query, engine)
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\base.py:1779, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1774 execution_options = self._execution_options.merge_with(
#    1775     execution_options
#    1776 )
#    1778 dialect = self.dialect
# -> 1779 ret = self._execute_context(
#    1780     dialect,
#    1781     dialect.execution_ctx_cls._init_statement,
#    1782     statement,
#    1783     None,
#    1784     execution_options,
#    1785     statement,
#    1786     distilled_parameters,
#    1787 )
#    1789 return ret
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File c:\Users\Darkles\10academy\10Academy-Kifiya-Week-2\env-week-2\Lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "MSISDN" does not exist
# LINE 3:                     "MSISDN" AS UserID,
#                             ^
#
# [SQL:
#                 SELECT
#                     "MSISDN" AS UserID,
#                     "Total DL (Bytes)" + "Total UL (Bytes)" AS TotalDataVolume,
#                     "Google UL (Bytes)" + "Google DL (Bytes)" AS ApplicationDataVolume
#                 FROM xdr_data
#                 ORDER BY TotalDataVolume DESC;
#             ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
df['Google'] = df['Google UL (Bytes)'] + df ['Google DL (Bytes)']
grouped_stats = df.groupby('Google')['total_data_volume'].describe()
grouped_stats.head(5)

# %%
df['Youtube'] = df['Youtube UL (Bytes)'] + df ['Youtube DL (Bytes)']
grouped_stats = df.groupby('Youtube')['total_data_volume'].describe()
grouped_stats.head(5)

# %%
df['Email'] = df['Email UL (Bytes)'] + df ['Email DL (Bytes)']
grouped_stats = df.groupby('Email')['total_data_volume'].describe()
grouped_stats.head(5)

# %%
df['Netflix'] = df['Netflix UL (Bytes)'] + df ['Netflix DL (Bytes)']
grouped_stats = df.groupby('Netflix')['total_data_volume'].describe()
grouped_stats.head(5)

# %%
df['Gaming'] = df['Gaming UL (Bytes)'] + df ['Gaming DL (Bytes)']
grouped_stats = df.groupby('Gaming')['total_data_volume'].describe()
grouped_stats.head(5)

# %%
df['Application'] = np.tile(['Google', 'Youtube', 'Email', 'Netflix', 'Gaming'], len(df) // 5 + 1)[:len(df)]
fig = plot_data(df, 'boxplot', x='Application', y='total_data_volume', title='Total_data_volume by Application', xlabel='Application', ylabel='total_data_volume', xticks_rotation=45)
plt.show(fig)

# %%
# Correlation on download data (DL)
columns_DL = ['Google DL (Bytes)', 'Email DL (Bytes)', 'Youtube DL (Bytes)', 'Netflix DL (Bytes)',  'Gaming DL (Bytes)']
correlation_matrix = df[columns_DL].corr()
correlation_matrix

# %%
# Visualize the correlation matrix using a heatmap
fig = plot_data(df, 'heatmap', data=correlation_matrix, title='Correlation Matrix of All Apps', xlabel='Apps', ylabel='Apps')
plt.show(fig)

# %%
# Correlation on upload data (UL)
columns_UL = [ 'Google UL (Bytes)','Email UL (Bytes)','Youtube UL (Bytes)','Netflix UL (Bytes)', 'Gaming UL (Bytes)']
correlation_matrix = df[columns_UL].corr()
correlation_matrix

# %%
# Visualize the correlation matrix using a heatmap
fig = plot_data(df, 'heatmap', data=correlation_matrix, title='Correlation Matrix of All Apps', xlabel='Apps', ylabel='Apps')
plt.show(fig)

# %%
# Select the columns for PCA (ensure they are numerical)
columns_for_pca =['Google DL (Bytes)', 'Google UL (Bytes)', 
               'Email DL (Bytes)', 'Email UL (Bytes)','Youtube DL (Bytes)', 
               'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)']
columns_for_pca = ['TotalUploadData', 'TotalDownloadData', 'TotalDataVolume']
pca_df = apply_pca(df, columns_for_pca, 2)

# %%
df_segmented_users = segment_users(df, 'TotalSessionDuration', 10)

# %%
decile_summary = compute_decile_summary(df, 'TotalSessionDurationDecile', ['TotalUsers', 'AvgDataVolume', 'MedianDataVolume'], ['count', 'mean', 'median'])

# %%
dispersion = compute_dispersion_measures(df, ['NumberOfSessions', 'TotalSessionDuration', 'TotalUploadData', 'TotalDownloadData'], ['mean', 'median', 'std', 'min', 'max'])

# %%
# Plot a histogram
fig = plot_data(df_cleaned, plot_type='histogram', x='TotalDownloadData', bins=20, kde=True, title='Download Data Histogram')
plt.show(fig)

# %%
# Plot a scatter plot
fig = plot_data(df_cleaned, plot_type='scatter', x='TotalDownloadData', y='TotalUploadData', title='Download vs Upload Data')
plt.show(fig)

# %%
# Plot a correlation heatmap
fig = plot_data(df_cleaned, plot_type='heatmap', title='Correlation Matrix')
plt.show(fig)

# %%
# Plot histograms
fig1 = plot_histogram(df_cleaned, ['NumberOfSessions', 'TotalSessionDuration', 'TotalUploadData', 'TotalDownloadData'])
plt.show(fig1)

# %%
# Plot boxplots
fig2 = plot_boxplot(df_cleaned, ['TotalUploadData', 'TotalDownloadData'])
plt.show(fig2)

# %%
# Plot scatter
fig3 = plot_scatter(df_cleaned, 'TotalDownloadData', 'TotalUploadData', "Download vs Upload Data")
plt.show(fig3)

# %%
# Plot correlation matrix
fig4 = plot_correlation_matrix(df_cleaned, ['TotalUploadData', 'TotalDownloadData', 'TotalDataVolume'])
plt.show(fig4)

# %% [markdown]
# # 2. Engagement Analysis

# %%
# Aggregate engagement metrics and get top 10 users for each metric
df_engagement = aggregate_engagement_metrics(df_cleaned)
top_10_session_frequency, top_10_session_duration, top_10_traffic = top_10_engagement(df_engagement)

# %%
# Plot Top 10 users for each metric for Session Frequency
fig = plot_top_10(df_engagement, 'SessionFrequency', xlabel='Customer ID (MSISDN)', ylabel='Sessions Frequency', title='Top 10 Users by Session Frequency')
plt.show()

# %%
# Plot Top 10 users for each metric for Session Duration
fig = plot_top_10(df_engagement, 'TotalSessionDuration', xlabel='Customer ID (MSISDN)', ylabel='Session Duration (seconds)', title='Top 10 Users by Session Duration')
plt.show()

# %%
# Plot Top 10 users for each metric for Total Traffic
fig = plot_top_10(df_engagement, 'TotalTraffic', xlabel='Customer ID (MSISDN)', ylabel='Total Traffic (bytes)', title='Top 10 Users by Total Traffic')
plt.show()

# %%
df_engagement = aggregate_engagement_metrics(df_cleaned)# Aggregate metrics
df_normalized = normalize_metrics(df_engagement)# Normalize metrics
df_clustered, kmeans_model = kmeans_clustering(df_normalized)# Apply K-Means clustering

cluster_stats = cluster_statistics(df_clustered)# Compute cluster statistics
cluster_stats

# %%
# Visualize
fig = plot_clusters(df_clustered)
fig.show()

# %%
# Top 10 users based on session frequency
fig1 = plot_top_10(df_engagement, 'SessionFrequency', xlabel='Customer ID (MSISDN)', ylabel='Sessions Frequency', title='Top 10 Users by Session Frequency')
fig1.show()

# %%
# Aggregate the engagement metrics (options: 'minmax' or 'zscore')
df_engagement = aggregate_engagement_metrics(df_cleaned)
df_normalized = normalize_metrics(df_engagement, normalize_type='minmax') # Normalize the engagement metrics
df_clustered = kmeans_clustering(df_normalized, n_clusters=3) # Perform K-means clustering

cluster_stats = cluster_statistics(df_clustered) # Calculate cluster statistics
cluster_stats

# %%
# Plot the top 3 most used applications
fig_top_apps = plot_top_applications(df_cleaned)
fig_top_apps.show()

# %%
# Visualize engagement metrics distribution
fig1 = plot_histogram(df_clustered)
fig1.show()

# %%
# Visualize K-means clustering
fig2 = plot_kmeans_clusters(df_clustered)
fig2.show()

# %%
# Visualize top 3 most used applications
top_users_per_app = aggregate_application_traffic(df_cleaned)# Aggregate the traffic per application
fig3 = plot_top_applications(top_users_per_app)
fig3.show()
